# %%
import gzip
from collections import defaultdict
import string
import random
from nltk.stem.porter import PorterStemmer 
import numpy

# %%
f=gzip.open('amazon_reviews_us_Gift_Card_v1_00.tsv','rt',encoder='utf8')
header=f.readline()
header=header.strip().split('\t')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b1703b43eb3a> in <module>()
# ----> 1 f=gzip.open('amazon_reviews_us_Gift_Card_v1_00.tsv',rt,encoder='utf8')
#       2 header=f.readline()
#       3 header=header.strip().split('\t')
#
# NameError: name 'rt' is not defined
