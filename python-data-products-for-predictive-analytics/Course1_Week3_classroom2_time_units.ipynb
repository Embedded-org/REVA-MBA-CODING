# %%
import time
import calendra
timestring='2018-07-26 01:36:02'

# %%
timestruct=time.strptime(timestring,'%Y-%m-%d %H:%M:%S')
timestruct
# Out:
# time.struct_time(tm_year=2018, tm_mon=7, tm_mday=26, tm_hour=1, tm_min=36, tm_sec=2, tm_wday=3, tm_yday=207, tm_isdst=-1)

# %%
time.gmtime(t1+60*60*24*5)

# %%
timestruct.tm_wday
# Out:
# 3

# %%
import calendar
t1=calendar.timegm(timestruct)
t1
# Out:
# 1532568962

# %%
t2=time.mktime(timestruct)
t2
# Out:
# 1532568962.0

# %%
t1+=60*60*24*5
t1
# Out:
# 1533000962

# %%
time.gmtime(t1+60*60*24*5)
# Out:
# time.struct_time(tm_year=2018, tm_mon=8, tm_mday=5, tm_hour=1, tm_min=36, tm_sec=2, tm_wday=6, tm_yday=217, tm_isdst=0)

# %%
time.strftime('%Y-%m-%d %H:%M:%S',time.gmtime(t1+60*60*24*5))
# Out:
# '2018-08-05 01:36:02'

# %%
import json
f=open('reviews.json','r',encoding='utf8')
dataset=[]
for i in range(10000):
  dataset.append(json.loads(f.readline()))
dataset[0]
# Out:
# {'business_id': 'XHYxwXtnidQsm89rE_OIUQ',
#  'cool': 0,
#  'date': '2016-11-22 01:48:06',
#  'funny': 0,
#  'review_id': 'QScdf32LViCASQirYGJ6hA',
#  'stars': 5.0,
#  'text': "WOW!! This company is amazing!!!!! As a full time working mom I can't tell you how hard it is to keep up with keeping the house clean. I am a neat freak and they came in and made my house so spotless. It is such a breath of fresh air coming home and knowing I don't have to worry about anything! My house is so shiny and it even smelled good! You guys did a fantastic job and we will definitely be contacting you again! This cleaning came at the perfect time and the cleaning ladies were so nice and friendly! Thank you so much! You have made a life long customer!",
#  'useful': 0,
#  'user_id': 'ZnZmF11O42qfhhNNA5juhA'}

# %%
timestring=dataset[0]['date']
timestring
# Out:
# '2016-11-22 01:48:06'

# %%
timestruct=time.strptime(timestring,'%Y-%m-%d %H:%M:%S')
timestruct
# Out:
# time.struct_time(tm_year=2016, tm_mon=11, tm_mday=22, tm_hour=1, tm_min=48, tm_sec=6, tm_wday=1, tm_yday=327, tm_isdst=-1)

# %%
time.strptime('21:36:10,28/5/2019','%H:%M:%S,%d/%m/%Y')
# Out:
# time.struct_time(tm_year=2019, tm_mon=5, tm_mday=28, tm_hour=21, tm_min=36, tm_sec=10, tm_wday=1, tm_yday=148, tm_isdst=-1)

# %%
timeint=time.mktime(timestruct)
timeint
# Out:
# 1479779286.0

# %%
timeint2=time.mktime(time.strptime(dataset[59]['date'],'%Y-%m-%d %H:%M:%S'))
timeint2
# Out:
# 1490593324.0

# %%
timediff=timeint-timeint2
timediff
# Out:
# -10814038.0

# %%
time.gmtime(timeint)
# Out:
# time.struct_time(tm_year=2016, tm_mon=11, tm_mday=22, tm_hour=1, tm_min=48, tm_sec=6, tm_wday=1, tm_yday=327, tm_isdst=0)

# %%
time.gmtime(timeint+60*60*24*7)
# Out:
# time.struct_time(tm_year=2016, tm_mon=11, tm_mday=29, tm_hour=1, tm_min=48, tm_sec=6, tm_wday=1, tm_yday=334, tm_isdst=0)

# %%
# !jupyter nbconvert Course1_Week3_classroom2_time_units.ipynb
# Out:
# [NbConvertApp] Converting notebook Course1_Week3_classroom2_time_units.ipynb to html
# [NbConvertApp] Writing 289817 bytes to Course1_Week3_classroom2_time_units.html
